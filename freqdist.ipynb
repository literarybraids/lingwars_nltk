# %% [markdown]
# # Cómo crear una distribución de frecuencias con NLTK

# %% [markdown]
# En este cuaderno, utilizaremos NLTK para hacer:
#
# * Una simple distribución de frecuencias. Partiendo de un archivo de texto, utilizaremos la clase FreqDist de NLTK para calcular el número de apariciones de las 30 palabras largas (de 8 o más símbolos) que más se usan en él.
#
# * Una distribución condicional. Partiendo de una lista de palabras y de dos archivos de texto, utilizaremos la clase ConditionalFreqDist de NLTK para calcular las frecuencias de cada palabra para cada texto.
#
# Por último, visualizaremos estos datos.

# %% [markdown]
# ## Pasos previos

# %% [markdown]
# En este cuaderno vamos a trabajar con dos archivos de texto: copus1.txt y corpus2.txt.
#
# Antes de empezar a calcular frecuencias, tenemos que "extraer" el texto de cada uno de los archivos y tokenizarlo, es decir segmentarlo por palabras. Estas operaciones ya han sido comentadas en el cuaderno "POS Tagging", así que puedes consultarlo en el caso de tener alguna duda.

# %%
from nltk.tokenize import word_tokenize

def extract_raw(filename):
    with open(filename, "r") as f:
        raw = f.readlines()
    raw = ' '.join(raw)
    return raw

raw1, raw2 = extract_raw('data/corpus1.txt'), extract_raw('data/corpus2.txt')

def tokenize_low(raw):
    tokens = word_tokenize(raw)
    tokens_low = [word.lower() for word in tokens]
    return tokens_low

tokens1, tokens2 = tokenize_low(raw1), tokenize_low(raw2)

# %%
# Para comprobar que todo se ha tokenizado bien, imprimimos por pantalla los 30 primeros tokens de cada lista
print(tokens1[:30], '\n', tokens2[:30])
# Out:
# ['prólogo', 'las', 'recomendaciones', 'de', 'mi', 'tía', 'úrsula', 'varias', 'veces', 'mi', 'tía', 'úrsula', 'me', 'habló', 'de', 'un', 'pariente', 'nuestro', ',', 'intrigante', 'y', 'conspirador', ',', 'enredador', 'y', 'libelista', '.', 'mi', 'tía', 'úrsula']
#  ['prólogo', 'se', 'empeña', 'don', 'miguel', 'de', 'unamuno', 'en', 'que', 'ponga', 'yo', 'un', 'prólogo', 'a', 'este', 'su', 'libro', 'en', 'que', 'se', 'relata', 'la', 'tan', 'lamentable', 'historia', 'de', 'mi', 'buen', 'amigo', 'augusto']

# %% [markdown]
# ## Contar apariciones de palabras

# %% [markdown]
# Para esta tarea, solo vamos a trabajar con la lista de tokens generada a partir del archivo corpus1.txt.
#
# Nuestro objetivo es contar el número de apariciones de cada palabra que tenga 8 o más caracteres. Es decir, queremos crear un objeto de este formato:
#         {'revolución': 3, 'lingüística': 5, 'neologismo': 8, etc.}
#
# La clase FreqDist de nltk, nos permite hacerlo de forma muy fácil.

# %%
from nltk import FreqDist

# %% [markdown]
# Sin embargo, primero tenemos que filtrar nuestra lista de tokens para solo dejar en ella los de 8 o más caracteres.

# %%
tokens_8 = [w for w in tokens1 if len(w) >= 8]

# 1. for w in tokens: cogemos uno por uno los elementos de la lista "tokens", refiriéndonos a cada elemento como w.
# 2. if len(w) >= 8: evaluamos si la longitud del elemento es igual o superior a 8, si no los es lo desechamos.
# 3. [w]: guardamos los elementos no desechados en nuestra nueva lista.

# %%
# Imprimimos por pantalla los 30 primeros tokens de nuestra nueva lista
print(tokens_8[:30])
# Out:
# ['recomendaciones', 'pariente', 'intrigante', 'conspirador', 'enredador', 'libelista', 'historia', 'caprichosa', 'afirmaba', 'pariente', 'figurado', 'políticos', 'afirmación', 'concretar', 'intervenido', 'entendía', 'políticos', 'político', 'revolución', 'francesa', 'aldeanos', 'borrachos', 'aseguraba', 'convicción', 'pariente', 'despejado', 'favorita', 'intención', 'maquiavélico', 'preocupación']

# %% [markdown]
# Una vez creada la lista, podemos crear la distribución de frecuencias y extraer de ella los datos que nos interesan.

# %%
# Creamos una distribución de frecuencias a partir de una lista de palabras de más de 8 caracteres
fdist = FreqDist(tokens_8)

# %%
# Imprimimos el número total de elementos en la distribución
types = fdist.N()
print("Hay {} elementos en la distribución.".format(types))
# Out:
# Hay 7936 elementos en la distribución.

# %%
# Imprimimos el número de apariciones de la palabra "políticos"
word = "políticos"
print("La palabra '{}' aparece {} veces en el texto.".format(word, fdist[word]))
# Out:
# La palabra 'políticos' aparece 14 veces en el texto.

# %%
# Imprimimos las 30 palabras más comunes. El resultado es una lista de tuplas. En cada tupla, en primera posición
# está el elemento y en segunda el número de apariciones de éste en el texto.
top30 = fdist.most_common(30)
print(top30)
# Out:
# [('aviraneta', 184), ('preguntó', 73), ('laguardia', 72), ('entonces', 58), ('contestó', 40), ('magdalena', 31), ('soldados', 31), ('muchacha', 28), ('carlistas', 27), ('estúñiga', 25), ('mientras', 25), ('liberales', 25), ('sanguinetti', 23), ('oficiales', 23), ('fernando', 23), ('etchepare', 23), ('personas', 23), ('tertulia', 22), ('piscinas', 21), ('bastante', 20), ('sociedad', 20), ('ejército', 19), ('sebastián', 19), ('sombrero', 18), ('entusiasmo', 18), ('calavera', 17), ('graciosa', 17), ('pariente', 16), ('españoles', 16), ('caballos', 16)]

# %% [markdown]
# Ahora vamos a ver dos maneras de representar de forma gráfica los datos obtenidos.

# %% [markdown]
# Primero utilizaremos el método plot. *Para poder utiizar el método plot es necesario tener instaladas las librerías matplotlib y numpy.*

# %%
fdist.plot(30, title='Palabras de 8 o más caracteres')

# %% [markdown]
# También podemos sacar provecho de la librería *wordcloud* de Python para crear una nube de palabras.
#
# En este cuaderno no vamos a comentar el uso de esta librería, pero te animamos a que [le eches un vistazo](https://github.com/amueller/word_cloud).

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = ' '.join(w[0] for w in top30)

wc = WordCloud(background_color="white", width=400, height=400)

wc.generate(text)

plt.imshow(wc, aspect='auto')
plt.show()

# %% [markdown]
# ### Tarea

# %% [markdown]
# Representar de forma gráfica el número de apariciones de las 20 palabras de exactamente 10 caracteres, que más se usan en el archivo corpus2.txt.
#
# *Tal vez te interese saber que en Python para evaluar si "a es igual a b" se puede usar la expresión* if a == b.

# %%
tokens2[:30]
tokens2_10 = [w for w in tokens2 if len(w) == 10]
fdist10 = FreqDist(tokens2_10)
top30 = fdist10.most_common(30)
plt.figure(figsize = (10,5))
#fdist10.plot(50)

import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = ' '.join(w[0] for w in top30)

wc = WordCloud(background_color="white", width=400, height=400)

wc.generate(text)
plt.imshow(wc, aspect='auto')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Distribución condicional

# %% [markdown]
# Dada una lista de palabras, queremos comparar las frecuencias con las que estas palabras aparecen en dos textos diferentes y visualizar los resultados.

# %%
# Palabras para las que queremos contar las frecuencias
words = ['vida', 'felicidad', 'peligro', 'amor', 'odio', 'muerte']

# %% [markdown]
# En primer lugar, queremos conseguir un objeto que tenga la siguiente estructura:
#
#       {'text1': {'perro': 2, 'gato': 3, ....}, 'text2': {'caballo': 5, 'ave': 1, ....}}
#
# Para hacerlo utilizaremos la clase ConditionalFreqDist de NLTK.

# %%
from nltk import ConditionalFreqDist

# %% [markdown]
# Para crear un objeto ConditionalFreqDist, le tenemos que pasar una lista que consiste de tuplas. El primer elemento  de cada tupla tiene que ser el nombre de la 'condición'. En nuestro caso, solo tenemos dos condiciones: 'text1' y 'text2'. El segundo elemento de cada tupla tiene que ser la propia palabra.
#
#        [('text1', 'perro'), (text1', 'gato')... ('text2', 'caballo'), ('text2', 'ave'), ('text2', 'pez')...]
#
# Nuestro primer paso será crear esta lista de tuplas a partir de las dos listas de tokens (tokens1 y tokens2) que tenemos.

# %%
texts = [('text1', tokens1), ('text2', tokens2)]
# Esta lista solo nos sirve para vincular las condiciones ('text1', 'text2') a sus respectivas listas 
# (tokens1, tokens2).  


texts_words = [(text[0], word)
               for text in texts
               for word in text[1]
              ]

# 1. for text in texts: cogemos cada tupla de nuestra lista 'texts'
# 2. text[1]: es el segundo elemento de la tupla. En este caso, el segundo elemento siempre es una lista de tokens.
# 3. for word in text[1]: cogemos cada token de lista de tokens.
# 4. (text[0], word): Creamos una tupla que contiene el nombre de la condición ('text1' o 'text2') y la propia palabra.

# %%
# Para comprabar que la lista se ha creado bien, imprimiremos sus 20 primeras y 20 últimos elementos.
print(texts_words[:20], '\n\n', texts_words[-20:])
# Out:
# [('text1', 'prólogo'), ('text1', 'las'), ('text1', 'recomendaciones'), ('text1', 'de'), ('text1', 'mi'), ('text1', 'tía'), ('text1', 'úrsula'), ('text1', 'varias'), ('text1', 'veces'), ('text1', 'mi'), ('text1', 'tía'), ('text1', 'úrsula'), ('text1', 'me'), ('text1', 'habló'), ('text1', 'de'), ('text1', 'un'), ('text1', 'pariente'), ('text1', 'nuestro'), ('text1', ','), ('text1', 'intrigante')]
#
#  [('text2', 'aquel'), ('text2', 'maravilloso'), ('text2', 'ejemplo'), ('text2', 'de'), ('text2', 'lealtad'), ('text2', 'y'), ('text2', 'fidelidad'), ('text2', '.'), ('text2', 'y'), ('text2', 'dijo'), ('text2', ':'), ('text2', '—¡y'), ('text2', 'luego'), ('text2', 'dirán'), ('text2', 'que'), ('text2', 'no'), ('text2', 'matan'), ('text2', 'las'), ('text2', 'penas'), ('text2', '!')]

# %% [markdown]
# Ya tenemos nuestra lista de tuplas, así que podemos crear una distribución condicional.

# %%
cfdist = ConditionalFreqDist(texts_words)
cfdist
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {'text1': FreqDist({'enciclopedista': 1,
#                                'canca': 1,
#                                'alumbrándose': 1,
#                                'sublevó': 1,
#                                'petróleo': 3,
#                                'instrucción': 1,
#                                'les': 36,
#                                'inclinó': 5,
#                                'quinta': 1,
#                                'tía': 13,
#                                'ayuntamiento': 6,
#                                'regiones': 2,
#                                'adoración': 1,
#                                'alumbraba': 1,
#                                'firmada': 1,
#                                'desenganchó': 1,
#                                'falda': 2,
#                                'arzobispo': 1,
#                                'introducir': 1,
#                                'gerundio_': 1,
#                                'ocurrida': 1,
#                                'ellos': 37,
#                                'habla': 4,
#                                'interrumpida': 1,
#                                'despertarlo': 1,
#                                'enseñanza': 2,
#                                '¿quieren': 1,
#                                'echegarayzando': 1,
#                                'milagro': 2,
#                                '_tocsin_': 1,
#                                'efigie': 1,
#                                'foco': 2,
#                                'médico': 1,
#                                'iremos': 2,
#                                'gruesos': 1,
#                                'cobertizo': 2,
#                                'es': 155,
#                                'declararse': 1,
#                                'favorecido': 2,
#                                'ahí': 21,
#                                'enérgica': 1,
#                                'invadir': 1,
#                                'corral': 4,
#                                'negros': 8,
#                                'para': 199,
#                                'larga': 11,
#                                'mascullando': 1,
#                                'pereyra': 4,
#                                'obreros': 1,
#                                'mandaron': 1,
#                                'propietario': 1,
#                                'quieran': 1,
#                                'ayudarás': 1,
#                                '?': 361,
#                                'inmortalidad': 1,
#                                'luchaban': 2,
#                                '¿las': 1,
#                                'curiosidad': 3,
#                                '35': 1,
#                                '«hala': 1,
#                                'contentos': 1,
#                                'malos': 4,
#                                'presentarse': 2,
#                                'peseta': 1,
#                                'equivocado': 1,
#                                'separación': 1,
#                                'piscina': 11,
#                                'necesito': 2,
#                                'puñalada': 2,
#                                'íbamos': 2,
#                                'prisioneros': 6,
#                                'saludo': 1,
#                                'arrasoyarequin': 1,
#                                'molestado': 2,
#                                'niño': 3,
#                                'antro': 1,
#                                'patriota': 4,
#                                '¿lo': 1,
#                                'interesase': 1,
#                                'garita': 1,
#                                'convencimiento': 1,
#                                'podríamos': 1,
#                                'parpadeó': 1,
#                                'pasajeros': 1,
#                                'rocas': 1,
#                                'mendigos': 1,
#                                '¿la': 3,
#                                'morir': 2,
#                                'ocupan': 1,
#                                'engañarnos': 2,
#                                '¡canallas': 1,
#                                'ermita': 1,
#                                'favor': 7,
#                                'dió': 25,
#                                'entallada': 1,
#                                'aislado': 1,
#                                'verdad': 23,
#                                'enredos': 3,
#                                'realidad': 7,
#                                'seguramente': 2,
#                                'asistente': 2,
#                                'erguía': 1,
#                                'vagabundos': 2,
#                                'conminó': 1,
#                                'densa': 1,
#                                'llevaran': 1,
#                                'escoger': 1,
#                                'hacerse': 3,
#                                'anduvo': 1,
#                                'digno': 1,
#                                'telas': 1,
#                                'luxemburgo': 1,
#                                'vascongado': 4,
#                                'nuestra': 9,
#                                'zuaznavar': 6,
#                                'enredada': 1,
#                                'indagaciones': 2,
#                                'contestaron': 1,
#                                'revueltas': 1,
#                                'marcharme': 2,
#                                'aderezarla': 1,
#                                'hicieron': 13,
#                                'concluyó': 3,
#                                'violencia': 6,
#                                'movimientos': 1,
#                                'trabuco': 6,
#                                'señaló': 1,
#                                'agua': 7,
#                                'lodo': 1,
#                                'falsas': 4,
#                                'callejones': 1,
#                                'gaspar': 4,
#                                'pasaporte': 1,
#                                'meglio': 1,
#                                'leguías': 1,
#                                '¿tiene': 4,
#                                'inventaba': 1,
#                                'gustan': 1,
#                                'cuándo': 2,
#                                'enfermizo': 1,
#                                'violentos': 1,
#                                'comandante': 5,
#                                'madre': 19,
#                                'desorganizadores': 1,
#                                'llegar': 22,
#                                'gracias': 7,
#                                'estos': 36,
#                                'tocará': 1,
#                                'ausencia': 1,
#                                'mutismo': 1,
#                                '¿todo': 2,
#                                'empresas': 2,
#                                'repartían': 1,
#                                'ponemos': 1,
#                                'abandono': 1,
#                                'dictaminara': 1,
#                                'sienes': 1,
#                                'vió': 24,
#                                'vegetales': 1,
#                                'romántica': 1,
#                                'puesto': 6,
#                                'muy': 97,
#                                'alarmas': 1,
#                                'retreta': 1,
#                                'múzquiz': 1,
#                                'revolucionarios': 6,
#                                'tendrán': 3,
#                                'sujetaron': 3,
#                                '¿para': 7,
#                                'dicen': 3,
#                                'pánico': 1,
#                                'tiró': 5,
#                                'así': 33,
#                                'trascendentales': 1,
#                                'enigmático': 1,
#                                'sentí': 2,
#                                'efusión': 1,
#                                'asesino': 1,
#                                'publicaba': 1,
#                                'rojizos': 1,
#                                'prácticas': 1,
#                                'grito': 9,
#                                'bidian': 1,
#                                'treviño': 1,
#                                'realización': 2,
#                                'brutal': 1,
#                                'recuerdo': 11,
#                                'brotaban': 1,
#                                'entusiasmaba': 1,
#                                'pleno': 2,
#                                'importantes': 2,
#                                'capucha': 1,
#                                'discutía': 1,
#                                'inmediatamente': 11,
#                                'haciéndose': 1,
#                                'urrolara': 3,
#                                'desprecio': 2,
#                                '¿en': 2,
#                                'pareció': 8,
#                                'sacarle': 2,
#                                'autoridad': 3,
#                                'colina': 2,
#                                'natural': 14,
#                                'cochecito': 1,
#                                'majeza': 2,
#                                'toca': 2,
#                                'nombró': 1,
#                                'preparando': 1,
#                                'oficialito': 1,
#                                'cristo': 1,
#                                'nunca': 16,
#                                'echando': 2,
#                                'determinación': 2,
#                                'probabilidades': 1,
#                                'reconocen': 1,
#                                'intentó': 3,
#                                'guerras': 1,
#                                'disgustaría': 1,
#                                'curas': 4,
#                                'menor': 4,
#                                'monté': 1,
#                                'prohibido': 1,
#                                'símbolos': 1,
#                                'montaperras': 2,
#                                'carnaval': 1,
#                                'daban': 6,
#                                'solemnidad': 1,
#                                'tercería': 1,
#                                'espere': 1,
#                                'impresión': 6,
#                                'casa': 178,
#                                'períodos': 1,
#                                'fuga': 2,
#                                'tranquilo': 4,
#                                'escribió': 10,
#                                'desgraciados': 1,
#                                'publicarlo': 2,
#                                'acaso': 1,
#                                'aviene': 1,
#                                'pregunta': 2,
#                                'próximo': 6,
#                                'moscardoneo': 1,
#                                'dieran': 1,
#                                'colores': 1,
#                                'llevé': 3,
#                                'fabulosa': 1,
#                                'pacto': 1,
#                                'triunfo': 4,
#                                'insólito': 1,
#                                'infecto': 1,
#                                'verte': 2,
#                                'prosista': 2,
#                                'disparar': 1,
#                                'demagogia': 1,
#                                'acordó': 2,
#                                'quemaba': 1,
#                                'saltar': 2,
#                                'abundante': 1,
#                                'azcoitia': 7,
#                                'grado': 5,
#                                'buscan': 1,
#                                'esperaban': 1,
#                                'cuente': 2,
#                                'estaba': 114,
#                                'prendió': 1,
#                                'chocolate': 1,
#                                'recados': 2,
#                                'descifre': 1,
#                                'transversal': 1,
#                                'bolsillo': 6,
#                                'teresa': 1,
#                                'marqués': 3,
#                                'hoyos': 2,
#                                'viaje': 3,
#                                'bodegón': 1,
#                                'rebeldía': 1,
#                                'encerrara': 1,
#                                'nacimiento': 3,
#                                'impusieron': 1,
#                                'pegaban': 1,
#                                'jefes': 6,
#                                'chiquita': 1,
#                                'piedad': 1,
#                                'tonadilla': 1,
#                                'botines': 1,
#                                'mayor': 23,
#                                'aspiraba': 1,
#                                'manuscrito': 1,
#                                'sabemos': 1,
#                                'fríamente': 1,
#                                'trazando': 1,
#                                'teja': 1,
#                                'charlatán': 1,
#                                'luego': 48,
#                                'separo': 1,
#                                'muchachos': 11,
#                                'luto': 4,
#                                'citó': 1,
#                                'filadelfos': 6,
#                                'sangrientos': 1,
#                                'dormir': 6,
#                                'principio': 4,
#                                'atajo': 1,
#                                'reía': 2,
#                                'compungida': 1,
#                                'conservaba': 2,
#                                'templados': 1,
#                                'ejércitos': 1,
#                                'azufre': 1,
#                                'talud': 1,
#                                'paseando': 3,
#                                'exagero': 1,
#                                'país': 12,
#                                'diseminados': 1,
#                                'madrid': 25,
#                                'suficiencia': 1,
#                                'viniendo': 1,
#                                'giro': 2,
#                                'pencos': 1,
#                                'probable': 1,
#                                'gastó': 1,
#                                'intentarán': 1,
#                                'montón': 3,
#                                'espeluznante': 2,
#                                'abogando': 1,
#                                'disolvieron': 1,
#                                'trató': 3,
#                                'sordas': 2,
#                                'otana': 1,
#                                'entraba': 4,
#                                'respetabilidad': 1,
#                                'lleva': 3,
#                                'comía': 1,
#                                'tribu': 1,
#                                'interrumpir': 1,
#                                'preeminencia': 1,
#                                'primavera': 1,
#                                'quizá': 14,
#                                'querida': 2,
#                                'grave': 4,
#                                'brillantes': 2,
#                                '¡cuánto': 1,
#                                'archaya': 2,
#                                'cogiéndola': 1,
#                                'quemar': 2,
#                                'embestidas': 1,
#                                'rubio': 2,
#                                'herradura': 2,
#                                'donna.»': 1,
#                                'espantosas': 1,
#                                'verse': 5,
#                                'observó': 1,
#                                'vela': 8,
#                                'truquenecoborda': 1,
#                                'causa': 12,
#                                'faroles': 1,
#                                'aventurero': 6,
#                                'intelectuales': 1,
#                                'pagado': 1,
#                                'resistencia': 1,
#                                'portillo': 2,
#                                'llamas': 3,
#                                'conspirador': 3,
#                                'iriberri': 2,
#                                'fracasó': 2,
#                                'pronto': 26,
#                                'miniatura': 2,
#                                'comprometerse': 1,
#                                'dolmán': 1,
#                                'abortado': 1,
#                                'encargos': 1,
#                                'obrar': 1,
#                                'almas': 1,
#                                'nací': 2,
#                                'bastante': 20,
#                                'guardar': 2,
#                                'datos': 2,
#                                'enemistades': 1,
#                                'molesta': 3,
#                                'blanquear': 1,
#                                'pedí': 2,
#                                'tallien': 2,
#                                'escalábamos': 1,
#                                'palo': 2,
#                                'generalizarse': 1,
#                                'corredor': 3,
#                                'burlones': 2,
#                                'chirriar': 1,
#                                'quedarnos': 3,
#                                'soltaron': 1,
#                                'pidiéndolos': 1,
#                                'pobremente': 2,
#                                'alrededores': 5,
#                                'lado': 25,
#                                'engaño': 1,
#                                'bebían': 1,
#                                'hacer': 64,
#                                'desnudarnos': 1,
#                                'véngate': 1,
#                                'venta': 6,
#                                'desdeñosos': 2,
#                                'insignificante': 1,
#                                'felipe': 2,
#                                'bromeando': 1,
#                                '¿verdad': 4,
#                                'saludado': 1,
#                                'fusilarle': 1,
#                                'calumnia': 1,
#                                'santander': 7,
#                                'apareciendo': 2,
#                                'húmedo': 1,
#                                '¿probablemente': 1,
#                                'servidumbre': 1,
#                                'gentes': 4,
#                                'flemático': 1,
#                                'caballería': 4,
#                                'caracol': 1,
#                                'ilusión': 2,
#                                'probablemente': 5,
#                                'quedaremos': 2,
#                                'presentarle': 1,
#                                'paso': 13,
#                                'hablaremos': 3,
#                                '¡si': 2,
#                                'varones': 4,
#                                'farol': 3,
#                                'enemistad': 1,
#                                'artesanos': 1,
#                                'preguntando': 1,
#                                'sacó': 16,
#                                'dejaban': 3,
#                                '20': 1,
#                                'prusiano': 1,
#                                'madres': 1,
#                                'maliciosa': 1,
#                                'derecho': 6,
#                                'restauración': 1,
#                                'flauta': 1,
#                                'materialismo': 1,
#                                'escondí': 1,
#                                'semia': 1,
#                                'corriendo': 2,
#                                'perros': 4,
#                                'unión': 2,
#                                'interiormente': 1,
#                                'míos': 3,
#                                'este': 94,
#                                'talento': 4,
#                                'otros': 38,
#                                'ocultar': 1,
#                                'luisa': 2,
#                                'amordazaron': 1,
#                                'llevaba': 20,
#                                'acentos': 1,
#                                'torres': 1,
#                                'ángel': 2,
#                                'quedamos': 4,
#                                'levanté': 1,
#                                'padre': 44,
#                                'defendido': 1,
#                                'reconocimiento': 1,
#                                'sucesos': 1,
#                                'vientre': 1,
#                                'acepté': 1,
#                                'defensores': 1,
#                                'confusión': 1,
#                                'zapatillas': 1,
#                                'abandonado': 1,
#                                'durar': 2,
#                                'fincas': 2,
#                                'construyendo': 1,
#                                'rechoncho': 1,
#                                'sociedades': 3,
#                                'gallinas': 1,
#                                'penetra': 1,
#                                'desesperado': 3,
#                                '33': 1,
#                                'ventas': 2,
#                                'subía': 4,
#                                '¿entonces': 1,
#                                'influir': 1,
#                                'serena': 2,
#                                'escopetas': 1,
#                                'vidrieras': 1,
#                                'gure': 1,
#                                'grotesco': 1,
#                                'influyó': 1,
#                                'borda': 1,
#                                '¿usted': 4,
#                                'robábamos': 1,
#                                'recorrió': 4,
#                                'eran': 46,
#                                'tradicionalismo': 2,
#                                'jansenista': 1,
#                                'sonrosadas': 1,
#                                'mota': 2,
#                                'índole': 1,
#                                'cogote': 1,
#                                'dantonianos': 1,
#                                'trompetas': 1,
#                                'frecuentaba': 2,
#                                'carácter': 8,
#                                'provocadores': 1,
#                                'bondad': 1,
#                                'algunos': 39,
#                                'campiña': 1,
#                                'char': 1,
#                                'rosellón': 1,
#                                'traían': 2,
#                                'escuac': 1,
#                                '(': 12,
#                                'incorporarlo': 1,
#                                'fuenlabrada': 1,
#                                'estremecerán': 1,
#                                'dices': 4,
#                                'tontería': 3,
#                                'volver': 10,
#                                'recobraron': 1,
#                                'aburres': 1,
#                                'agobiado': 1,
#                                'sorprender': 1,
#                                'risa': 2,
#                                'mayoría': 7,
#                                'salamanca': 2,
#                                'silencio': 7,
#                                'fuera': 35,
#                                'confidencias': 1,
#                                'servicial': 1,
#                                'dú': 1,
#                                'ramón': 2,
#                                'mostrara': 1,
#                                'quédate': 1,
#                                'desde': 68,
#                                'suponer': 3,
#                                'cebada': 1,
#                                'vacaciones': 1,
#                                'detalles': 4,
#                                'madrileñas': 1,
#                                'granujería': 1,
#                                'profusamente': 1,
#                                'salta': 1,
#                                'campañas': 1,
#                                'libremente': 1,
#                                'diabluras': 1,
#                                'exterior': 5,
#                                'blancas': 2,
#                                'recaían': 1,
#                                'abogado': 2,
#                                'alforja': 1,
#                                'jugarse': 1,
#                                'figurándome': 1,
#                                'pregúntale': 1,
#                                'mil': 2,
#                                'tramado': 1,
#                                'coman': 1,
#                                'dómine': 2,
#                                'estiércol': 2,
#                                'levita': 2,
#                                'málaga': 1,
#                                'duro': 2,
#                                'refugiamos': 1,
#                                'canciones': 5,
#                                'suizo': 1,
#                                'verlos': 1,
#                                'calentado': 1,
#                                'obscureciera': 1,
#                                'furiosa': 3,
#                                'comió': 2,
#                                'quedarte': 1,
#                                'atrevido': 4,
#                                'materialista': 1,
#                                'insultado': 2,
#                                'sagaz': 1,
#                                'compró': 1,
#                                'armados': 2,
#                                'almudena': 1,
#                                'alargó': 2,
#                                'ésta': 9,
#                                'balas': 3,
#                                'basados': 1,
#                                'repartía': 2,
#                                'pintada': 1,
#                                'repertorio': 1,
#                                'sopa': 3,
#                                'firmando': 1,
#                                'llamándole': 1,
#                                'realistas': 12,
#                                'diálogo': 1,
#                                'estábamos': 5,
#                                'torero': 1,
#                                'careta': 1,
#                                'escu': 1,
#                                'nosotros': 15,
#                                '40': 1,
#                                'viveza': 3,
#                                'álamo': 1,
#                                'audaz': 5,
#                                'comerciantes': 1,
#                                'herejías': 1,
#                                'decíamos': 1,
#                                'contribuyendo': 1,
#                                'civil': 7,
#                                'rivalidades': 1,
#                                'estuviera': 5,
#                                'fuertemente': 2,
#                                'prosperará': 1,
#                                'acercó': 23,
#                                'tomarlos': 1,
#                                'granos': 2,
#                                'desligado': 1,
#                                'padece': 1,
#                                'maíces': 1,
#                                'une': 1,
#                                'viene': 6,
#                                '¿esto': 2,
#                                'urruña': 1,
#                                'sentimental': 1,
#                                'íntegros': 2,
#                                'folleto': 1,
#                                'dolores': 6,
#                                'tiene': 34,
#                                'insignificantes': 1,
#                                'implantar': 1,
#                                'simpática': 1,
#                                'alcobas': 2,
#                                'tranquila': 2,
#                                'danton': 8,
#                                'listo': 2,
#                                'neptuno': 1,
#                                'parecían': 4,
#                                '¡pse': 3,
#                                'guicciardini': 1,
#                                'monarquía': 3,
#                                'morar': 1,
#                                '¡hombre': 7,
#                                'brillaban': 1,
#                                'conocéis': 1,
#                                'maduras': 1,
#                                'transfigurado': 1,
#                                'moulins': 1,
#                                'palmadas': 2,
#                                'tanto': 14,
#                                'nacional': 4,
#                                'patrona': 2,
#                                '¿puedes': 1,
#                                'está': 42,
#                                'satírico': 1,
#                                'gime': 1,
#                                'daño': 2,
#                                'manifestaban': 1,
#                                'batalla': 2,
#                                'mendicidad': 1,
#                                'benedícite': 1,
#                                'berlina': 2,
#                                'arder': 1,
#                                'carlos': 6,
#                                'escuálido': 1,
#                                'estrasburgo': 1,
#                                'extranjeros': 1,
#                                'azulados': 1,
#                                'grandezas': 2,
#                                'creas': 1,
#                                'mínimo': 1,
#                                'dedicaron': 1,
#                                'perdió': 1,
#                                'vara': 1,
#                                'destaca': 1,
#                                'parisiense': 1,
#                                '¿están': 1,
#                                'esforzándose': 1,
#                                'pared': 10,
#                                'hagas': 1,
#                                'mantenía': 1,
#                                'impurezas': 1,
#                                'militares': 11,
#                                'cómicos': 1,
#                                'danzatu': 1,
#                                'triste': 4,
#                                'informes': 2,
#                                'plutón': 1,
#                                'indicarte': 1,
#                                'rubios': 1,
#                                'blasfemia': 2,
#                                'pasaban': 4,
#                                'repúblicas': 1,
#                                'madrileños': 1,
#                                'fracasado': 1,
#                                'lomas': 1,
#                                'respectivos': 1,
#                                'secretas': 1,
#                                'leche': 1,
#                                'jacques': 2,
#                                'enviaría': 1,
#                                'abrieron': 2,
#                                'viña': 1,
#                                'servido': 2,
#                                'ataque': 3,
#                                'agradable': 2,
#                                'agentes': 2,
#                                'hevia': 3,
#                                'echaré': 1,
#                                '_lamías_': 2,
#                                'recién': 4,
#                                'diez': 9,
#                                'encarnada': 1,
#                                'costillas': 1,
#                                'partidaria': 1,
#                                'hacia': 32,
#                                'jugando': 1,
#                                'pegamos': 1,
#                                'lazo': 2,
#                                'meterse': 5,
#                                '¿cuándo': 1,
#                                'mí': 39,
#                                'seule': 1,
#                                'lectura': 2,
#                                'antonieta': 1,
#                                'erosi': 1,
#                                'bandada': 1,
#                                'sangre': 7,
#                                'pasamos': 2,
#                                'volubilidad': 1,
#                                'sectas': 1,
#                                'acababan': 4,
#                                'engaña': 3,
#                                'marchitas': 1,
#                                'gobernatzendu': 1,
#                                'galerías': 4,
#                                'ficción': 2,
#                                'enciclopedismo': 2,
#                                'positivistas': 1,
#                                'sobrina': 6,
#                                'jactaba': 1,
#                                'aguadores': 1,
#                                'eh': 3,
#                                'recordó': 1,
#                                'derrotas': 1,
#                                'definido': 1,
#                                'dirige': 4,
#                                'quiso': 6,
#                                'ditirambos': 1,
#                                'novelas': 1,
#                                'tienes': 9,
#                                'hospedado': 1,
#                                'dejaron': 3,
#                                'cinta': 1,
#                                'viajar': 1,
#                                'secretos': 1,
#                                'boína': 7,
#                                'indiferencia': 7,
#                                'nevadas': 1,
#                                'íntima': 2,
#                                'montados': 1,
#                                'mi': 167,
#                                'estamos': 7,
#                                'moler': 2,
#                                'pelos': 1,
#                                'campana': 2,
#                                'ribavellosa': 7,
#                                'villarrealco': 1,
#                                'siguiente': 14,
#                                'comparsa': 1,
#                                'dirigido': 4,
#                                'infantes': 1,
#                                'dije': 13,
#                                'llega': 2,
#                                'detuvieron': 1,
#                                '¿cierro': 1,
#                                'ancho': 2,
#                                'despidieron': 1,
#                                'influencia': 6,
#                                'disparates': 1,
#                                'tenidas': 1,
#                                'mis': 30,
#                                'consiguió': 3,
#                                'questo': 1,
#                                'sorprendió': 2,
#                                'adelante»': 1,
#                                'entendía': 1,
#                                'rodeado': 2,
#                                'iglesias': 6,
#                                'francos': 2,
#                                'bruscamente': 2,
#                                'hilarión': 1,
#                                'las': 447,
#                                'alborotó': 1,
#                                'cojan': 1,
#                                'barco': 7,
#                                'obscureciendo': 1,
#                                'sea': 8,
#                                'aldeas': 1,
#                                'mendigo': 2,
#                                'pálidos': 2,
#                                'vistas': 1,
#                                'teorías': 1,
#                                'carretera': 13,
#                                'agitan': 1,
#                                'posible': 11,
#                                'borrachos': 1,
#                                'clootz': 3,
#                                'vas': 5,
#                                'mental': 1,
#                                'parezcan': 1,
#                                'terrenos': 2,
#                                'aristocrático': 3,
#                                'obra': 3,
#                                'resultas': 1,
#                                'moderno': 1,
#                                'agresiva': 1,
#                                'furor': 1,
#                                'premio': 1,
#                                'suscripción': 1,
#                                '«ese': 1,
#                                'oyendo': 1,
#                                'simpleza': 1,
#                                'infantería': 1,
#                                'cantados': 1,
#                                'caserío': 18,
#                                'maquinalmente': 1,
#                                '¡de': 1,
#                                'marca': 1,
#                                'legado': 1,
#                                'estrechos': 1,
#                                'vivir»': 1,
#                                'profundamente': 2,
#                                'parte': 30,
#                                'humo': 3,
#                                'mateo': 1,
#                                'sa': 1,
#                                'podían': 1,
#                                'agarró': 2,
#                                'ciertamente': 2,
#                                'especiales': 1,
#                                'estupefactos': 1,
#                                'creí': 1,
#                                'soltera': 2,
#                                'traído': 1,
#                                'silueta': 1,
#                                'palacio': 5,
#                                'historia': 14,
#                                'habilitada': 1,
#                                'llenos': 1,
#                                'eso': 43,
#                                'llamada': 3,
#                                'tonta': 1,
#                                'deshaciéndose': 1,
#                                'ligero': 1,
#                                'hablan': 2,
#                                'española': 3,
#                                'denominados': 1,
#                                'cubos': 2,
#                                'dueño': 4,
#                                'horriblemente': 1,
#                                'llamaban': 8,
#                                'credo': 2,
#                                'pensamos': 1,
#                                'patio': 7,
#                                'hablábamos': 2,
#                                'tuvierais': 1,
#                                'manubrio': 1,
#                                'reino': 2,
#                                'inteligencia': 4,
#                                'trigo': 1,
#                                'saliente': 1,
#                                'países': 1,
#                                'excéntrico': 1,
#                                'metió': 2,
#                                'benito': 2,
#                                'lavó': 1,
#                                'rodeados': 1,
#                                'consecuencias': 1,
#                                'puertecilla': 1,
#                                'quinqué': 2,
#                                'hundida': 1,
#                                'portu': 1,
#                                'pusiera': 1,
#                                'señoritas': 3,
#                                'majo': 1,
#                                'favorecer': 1,
#                                'abigarrado': 1,
#                                'discutían': 1,
#                                'gontrán': 1,
#                                'firma': 2,
#                                'oir': 9,
#                                'garitos': 1,
#                                'costó': 1,
#                                'gaztelumendi': 3,
#                                'hablaron': 4,
#                                'vieja': 43,
#                                'absoluta': 1,
#                                'infundirme': 1,
#                                'miserable': 1,
#                                'prado': 1,
#                                'salada': 1,
#                                'sufrido': 1,
#                                'dependiente': 1,
#                                'penalidades': 1,
#                                'crees': 2,
#                                'áspero': 1,
#                                'fosco': 1,
#                                'sol': 13,
#                                'democrático': 1,
#                                'babilonia': 1,
#                                'bárbara': 1,
#                                '¡estás': 1,
#                                'guardadores': 1,
#                                'visitar': 3,
#                                'blancura': 1,
#                                'siniestro': 2,
#                                'girondino': 2,
#                                'cizaña': 1,
#                                'orientarme': 1,
#                                'tacos': 1,
#                                'prudencia': 1,
#                                'pies': 5,
#                                'proyecto': 5,
#                                'parecerá': 1,
#                                'laster': 1,
#                                'tornaron': 1,
#                                'conocidos': 1,
#                                'carmín': 1,
#                                'pedazos': 5,
#                                'cerraban': 1,
#                                'mancha': 2,
#                                'religión': 5,
#                                'lord': 2,
#                                'solo': 11,
#                                'tomó': 8,
#                                'monstruos': 1,
#                                'sembrar': 1,
#                                'confidente': 1,
#                                'detuvo': 3,
#                                'varias': 29,
#                                '¿os': 1,
#                                'encabritado': 1,
#                                'patrocinaba': 1,
#                                'castaña': 1,
#                                'conspirar': 1,
#                                'ayudante': 1,
#                                'disfrazadas': 1,
#                                'jaungoicaren': 1,
#                                'primita': 1,
#                                'cieno': 1,
#                                'habrían': 1,
#                                'inutilidad': 2,
#                                'canalla': 6,
#                                'sabes': 9,
#                                'ilustración': 1,
#                                'entretenida': 1,
#                                'entraban': 6,
#                                'caballo': 23,
#                                'sabrás': 1,
#                                'costado': 1,
#                                'interiores': 1,
#                                'alegres': 1,
#                                'recomendada': 1,
#                                'verdadera': 5,
#                                'interesa': 1,
#                                'catarro': 1,
#                                'rondalla': 1,
#                                'debe': 6,
#                                'cuidaba': 1,
#                                'ventana': 25,
#                                'respecto': 1,
#                                'ducados': 1,
#                                'corneja': 1,
#                                'comprendí': 4,
#                                'mostraba': 4,
#                                'asientos': 1,
#                                'discípulo': 1,
#                                'véalo': 1,
#                                'magníficas': 1,
#                                'merino': 4,
#                                '¿vino': 1,
#                                'podrás': 1,
#                                'bene': 1,
#                                'concepto': 2,
#                                'escuelas': 2,
#                                'cuya': 6,
#                                'fusilado': 2,
#                                'facha': 1,
#                                '_rispetivo_': 1,
#                                'profundos': 2,
#                                'sorpresa': 6,
#                                'guerreado': 1,
#                                'itzea': 3,
#                                'republicano': 6,
#                                'acordaron': 1,
#                                'forma': 2,
#                                'estancia': 1,
#                                'actitudes': 2,
#                                'clases': 4,
#                                'batallas': 1,
#                                'funcionaron': 1,
#                                'batía': 1,
#                                'peor': 4,
#                                'revolvía': 1,
#                                'plan': 3,
#                                'gitanos': 1,
#                                'recostó': 1,
#                                ...}),
#                      'text2': FreqDist({'familiaridad': 1,
#                                'admitir': 1,
#                                'recibido': 3,
#                                'decir': 75,
#                                'desnúdame': 1,
#                                '—vamos': 14,
#                                'abríasele': 1,
#                                'perturbase': 1,
#                                'les': 32,
#                                'interesantísimo': 1,
#                                'ensalada': 1,
#                                'tía': 29,
#                                'lucharemos': 4,
#                                'acopio': 1,
#                                'introducir': 1,
#                                'ellos': 32,
#                                'margarita': 9,
#                                'enseñanza': 1,
#                                'cuervos': 1,
#                                'arregle': 1,
#                                'decía—': 5,
#                                'médico': 9,
#                                'retroceso': 1,
#                                'completarse': 1,
#                                '»y': 4,
#                                'contando': 1,
#                                'eco': 1,
#                                '—contestó': 2,
#                                'es': 776,
#                                'criaturas': 1,
#                                '—¡cállate': 2,
#                                'afea': 2,
#                                'ahí': 21,
#                                '—hombres': 1,
#                                '¡se': 7,
#                                'negros': 1,
#                                'para': 254,
#                                'larga': 1,
#                                'produce': 1,
#                                '—¿por': 6,
#                                'cómodamente': 1,
#                                '—¿paternos': 1,
#                                'quieran': 2,
#                                'vuelve': 4,
#                                'ayudarás': 2,
#                                'carrascal': 3,
#                                '?': 928,
#                                'inmortalidad': 2,
#                                'garzos': 1,
#                                'conventuales': 1,
# ...
#                                'trabajo': 27,
#                                'figúrate': 3,
#                                'echa': 5,
#                                'fuertemente': 1,
#                                'venderte': 1,
#                                'servicios': 1,
#                                'incidentes': 1,
#                                'acercó': 3,
#                                'reventado': 1,
#                                'geniecito': 1,
#                                'padece': 1,
#                                'vegetarianismo': 1,
#                                'llegará': 1,
#                                'viene': 19,
#                                'indignidad—exclamó': 1,
#                                '¿esto': 1,
#                                '—como': 20,
#                                'maridos': 1,
#                                'sinfonía': 1,
#                                'sentada': 1,
#                                'crecer': 1,
#                                'terram_': 1,
#                                'aceptó': 3,
#                                'tiene': 74,
#                                'presupuesto': 1,
#                                'insignificantes': 2,
#                                'tranquila': 1,
#                                'imaginé': 1,
#                                'listo': 1,
#                                'parecían': 4,
#                                'estudió': 5,
#                                'errónea': 1,
#                                'sacas': 2,
#                                'oscuro': 5,
#                                'trabaje': 3,
#                                '—cállate': 3,
#                                'puntual': 1,
#                                'nacional': 2,
#                                'revestir': 1,
#                                'liturgia': 1,
#                                'patrona': 9,
#                                'está': 87,
#                                'tratar': 1,
#                                'diciéndote': 1,
#                                '—muy': 2,
#                                'apartándole': 1,
#                                'envejecen': 1,
#                                'resistirme': 1,
#                                'confundirá': 1,
#                                'retortero': 1,
#                                'incendio': 2,
#                                'hazlo': 1,
#                                'ponga': 6,
#                                'rita': 3,
#                                'mínimo': 2,
#                                'perdió': 2,
#                                'parisiense': 1,
#                                'desnudos': 1,
#                                'hagas': 4,
#                                'mantenía': 1,
#                                'absoluto': 2,
#                                'triste': 8,
#                                'informes': 1,
#                                'ansia': 3,
#                                'leche': 5,
#                                'sucumbimos': 1,
#                                'señorones': 1,
#                                'legítimo': 1,
#                                'tempestades': 1,
#                                'solar': 1,
#                                'demostrando': 1,
#                                'servido': 4,
#                                'ataque': 3,
#                                'agentes': 1,
#                                'visten': 1,
#                                'recién': 5,
#                                'diez': 4,
#                                'espléndido': 2,
#                                'mía—': 1,
#                                'líos': 2,
#                                'escritores': 3,
#                                'hacia': 7,
#                                'recelosidad': 1,
#                                'terremoto': 1,
#                                'despedirlo': 1,
#                                'transcurrido': 1,
#                                'lazo': 1,
#                                'meterse': 2,
#                                'mí': 109,
#                                'lectura': 3,
#                                'pretendiente': 3,
#                                'contagiarse': 1,
#                                'habérsete': 1,
#                                'traeré': 2,
#                                'entendimiento': 1,
#                                'cruzado': 1,
#                                'selló': 1,
#                                'alzó': 1,
#                                'deuda': 2,
#                                'engaña': 2,
#                                '—¿que': 2,
#                                'entes': 5,
#                                '—¡víctima': 1,
#                                'dilataba': 1,
#                                'madera': 1,
#                                'sobrina': 12,
#                                'últimamente': 2,
#                                'eh': 3,
#                                'definido': 1,
#                                'cegado': 1,
#                                '—es': 42,
#                                'piensen': 1,
#                                'dirige': 2,
#                                'pecuniaria': 2,
#                                'durmiendo—le': 1,
#                                'contestarla': 1,
#                                'quiso': 7,
#                                'molestias': 3,
#                                'solazarse': 1,
#                                'novelas': 6,
#                                'tienes': 21,
#                                'hábito': 1,
#                                'despierte': 2,
#                                'combativo': 1,
#                                'raya': 1,
#                                'pormenores': 1,
#                                '¡majestuosa': 1,
#                                'secretos': 4,
#                                'llevas': 3,
#                                'indiferencia': 1,
#                                'nevadas': 1,
#                                '¡hipocresía': 1,
#                                'estatuaria': 1,
#                                'papá': 1,
#                                'perladas': 1,
#                                'íntima': 7,
#                                'alumbrando': 1,
#                                'erudición': 1,
#                                'rodando': 1,
#                                '—¡mire': 1,
#                                'resolver': 1,
#                                'maliciosamente': 1,
#                                'acabé': 2,
#                                'adquiere': 1,
#                                'confundirse': 1,
#                                'tuvieras': 1,
#                                'mi': 295,
#                                'estamos': 6,
#                                'valerte': 1,
#                                'recrea': 1,
#                                '¡mujeres': 2,
#                                'siguiente': 5,
#                                'kultura': 1,
#                                '¿volverás': 1,
#                                'genérico': 2,
#                                'dirigido': 3,
#                                'sucesión': 1,
#                                '—¿querrías': 1,
#                                'dije': 24,
#                                'llega': 6,
#                                'deploraba': 1,
#                                'despidieron': 1,
#                                'influencia': 1,
#                                'disparates': 3,
#                                'empezar': 5,
#                                'cerebros': 1,
#                                'poniéndose': 5,
#                                'cambiará': 1,
#                                'sorprendió': 1,
#                                'entendía': 3,
#                                'bruscamente': 3,
#                                'atravesó': 1,
#                                'las': 288,
#                                '_nivolesca_': 1,
#                                'mónadas': 1,
#                                'bóveda': 1,
#                                'sea': 55,
#                                'das': 2,
#                                'despidiéronse': 1,
#                                'mendigo': 2,
#                                '—¿eh': 2,
#                                'preguntarme': 1,
#                                'embarazo': 2,
#                                'teorías': 1,
#                                'representa': 1,
#                                'oírme': 1,
#                                'recurrió': 1,
#                                'decirse': 4,
#                                'posible': 10,
#                                'tomen': 1,
#                                'vas': 9,
#                                'obra': 5,
#                                'llovía': 2,
#                                'encentaba': 1,
#                                'fábrica': 1,
#                                'melancólico': 4,
#                                'oyendo': 3,
#                                '—decía': 2,
#                                'huída': 1,
#                                'movemos': 1,
#                                'llegas': 1,
#                                'verá': 7,
#                                'lanzadera': 1,
#                                'maquinalmente': 1,
#                                '¡de': 9,
#                                'todos': 53,
#                                'consolarme': 1,
#                                'palomina': 1,
#                                'legado': 2,
#                                'sueñan': 2,
#                                'profundamente': 4,
#                                'parte': 27,
#                                'humo': 1,
#                                'puede': 58,
#                                'noches': 8,
#                                'grueso': 1,
#                                '_¡la': 1,
#                                'podían': 1,
#                                'ingenua': 3,
#                                '¿tiene': 3,
#                                'creencias': 1,
#                                'disponía': 1,
#                                'guapas': 1,
#                                'creí': 13,
#                                'aprendierais': 1,
#                                'soltera': 2,
#                                'ofensas': 1,
#                                '«aquí': 3,
#                                'traído': 3,
#                                'olimpo': 1,
#                                '—cásate': 2,
#                                'caminos': 4,
#                                'arrimadito': 1,
#                                'historia': 21,
#                                'llenos': 1,
#                                'quietecito': 2,
#                                'recordarme': 1,
#                                'eso': 186,
#                                'predicador': 1,
#                                'insinuado': 2,
#                                'hablan': 1,
#                                'arqueólogo': 2,
#                                'española': 1,
#                                'enamoraste': 1,
#                                'burlar': 2,
#                                'pintores': 1,
#                                'dueño': 1,
#                                'notar': 1,
#                                'horriblemente': 2,
#                                'mujer—interpeló': 1,
#                                'viste': 3,
#                                'perjudicando': 2,
#                                'molestaría': 1,
#                                'ladrarnos': 1,
#                                'acabada': 1,
#                                'manubrio': 2,
#                                'inteligencia': 3,
#                                'rosario.»': 1,
#                                'saliente': 1,
#                                'afrodisíacas': 1,
#                                'haberme': 6,
#                                'metió': 2,
#                                'prudencio': 1,
#                                'pingües': 1,
#                                '158': 1,
#                                'fortuita': 3,
#                                'paternal': 1,
#                                'lavó': 2,
#                                'ganarlas': 3,
#                                'consecuencias': 3,
#                                'desfiguramiento': 1,
#                                'recibirla': 1,
#                                'acata': 1,
#                                'acostumbrándonos': 1,
#                                'sonreía': 5,
#                                'desahogo': 4,
#                                'exactamente': 1,
#                                'echarse': 2,
#                                'candidato': 3,
#                                'oir': 12,
#                                'solicitante': 2,
#                                'lavóse': 1,
#                                'doy': 5,
#                                'fermín—': 5,
#                                'ceniza': 2,
#                                'vieja': 1,
#                                'luminosa': 3,
#                                'anunció': 1,
#                                'sostener': 2,
#                                'suplir': 1,
#                                'absoluta': 2,
#                                'estéril': 2,
#                                'revertió': 1,
#                                '—obedece': 1,
#                                'sufrido': 1,
#                                'antojo': 2,
#                                'despachaste': 1,
#                                'crees': 17,
#                                'áspero': 1,
#                                '¿domingo': 1,
#                                'sol': 10,
#                                'viviese': 2,
#                                'vuelvas': 1,
#                                'lengüeta': 1,
#                                'arrancóle': 1,
#                                'engañado': 10,
#                                'bárbara': 1,
#                                'comí': 1,
#                                'despachado': 2,
#                                'dudase': 2,
#                                'admirar': 1,
#                                'sacrificarme': 2,
#                                'pensarías': 1,
#                                'visitar': 1,
#                                '¿supongo': 1,
#                                'pesimista': 3,
#                                'devotos': 1,
#                                'sepamos': 2,
#                                'disparatado': 1,
#                                'perra': 4,
#                                'agridulce': 1,
#                                'pies': 9,
#                                'sazonado': 1,
#                                'yo—dijo': 1,
#                                'parecerá': 1,
#                                'conocidos': 1,
#                                '—mire': 4,
#                                'respuesta': 2,
#                                'manía': 3,
#                                'desdichada': 1,
#                                'sentarla': 1,
#                                'empezarás': 1,
#                                'cerraban': 1,
#                                'escojer': 1,
#                                'religión': 10,
#                                'solo': 27,
#                                'tomó': 8,
#                                'lutos': 2,
#                                'exaltarme': 2,
#                                'existencia—la': 1,
#                                'teoría—añadió—': 1,
#                                'confidente': 3,
#                                'detuvo': 2,
#                                'excusas': 1,
#                                'varias': 3,
#                                '¿os': 2,
#                                'sigue': 5,
#                                'directo': 1,
#                                'recorría': 1,
#                                ...})})

# %% [markdown]
# Las frecuencias que aparecen en esta distribución son absolutas, es decir corresponden al número real de apariciones de cada palabra. Sin embargo, nuestros dos textos no tienen la misma longitud y por eso estas frecuencias no son directamente comparables. Lo que realmente nos interesa comparar son las frecuencias relativas.
#
# NLTK no permite hacer una distribución de este tipo, así que tendremos que utilizar un pequeño "hack" para conseguirlo. En este caso, queremos conseguir las frecuencias por cada 10000 tokens.

# %%
from copy import copy, deepcopy

rel_cfdist = deepcopy(cfdist) # Creamos una copia de la distribución condicional

# Creamos copias de cada una de las distribuciones de frecuencias
rel_fdist1 = copy(cfdist['text1'])
rel_fdist2 = copy(cfdist['text2'])

def fdist_per(fd, length, per=10000):
    """
    INPUT:
       - fd: objeto FreqDist
       - length: número total de tokens en el texto
       - per: por cada cuántos tokens queremos obtener la frecuencia relativa
    OUTPUT: nuevo objeto FreqDist con frecuencias por cada X palabras      
    """
    for key, value in fd.items():
        fd[key] = round(value / length * per, 3)
    return fd

rel_cfdist['text1'] = fdist_per(rel_fdist1, len(tokens1))
rel_cfdist['text2'] = fdist_per(rel_fdist2, len(tokens2))

rel_cfdist
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {'text1': FreqDist({'enciclopedista': 0.167,
#                                'canca': 0.167,
#                                'alumbrándose': 0.167,
#                                'sublevó': 0.167,
#                                'petróleo': 0.501,
#                                'instrucción': 0.167,
#                                'les': 6.016,
#                                'inclinó': 0.836,
#                                'quinta': 0.167,
#                                'tía': 2.173,
#                                'ayuntamiento': 1.003,
#                                'regiones': 0.334,
#                                'adoración': 0.167,
#                                'alumbraba': 0.167,
#                                'firmada': 0.167,
#                                'desenganchó': 0.167,
#                                'arzobispo': 0.167,
#                                'introducir': 0.167,
#                                'gerundio_': 0.167,
#                                'ocurrida': 0.167,
#                                'ellos': 6.183,
#                                'habla': 0.668,
#                                'despertarlo': 0.167,
#                                'enseñanza': 0.334,
#                                '¿quieren': 0.167,
#                                'echegarayzando': 0.167,
#                                'milagro': 0.334,
#                                '_tocsin_': 0.167,
#                                'efigie': 0.167,
#                                'foco': 0.334,
#                                'médico': 0.167,
#                                'iremos': 0.334,
#                                'gruesos': 0.167,
#                                'cobertizo': 0.334,
#                                'es': 25.903,
#                                'declararse': 0.167,
#                                'favorecido': 0.334,
#                                'ahí': 3.509,
#                                'enérgica': 0.167,
#                                'invadir': 0.167,
#                                'corral': 0.668,
#                                'negros': 1.337,
#                                'para': 33.256,
#                                'larga': 1.838,
#                                'mascullando': 0.167,
#                                'pereyra': 0.668,
#                                'obreros': 0.167,
#                                'mandaron': 0.167,
#                                'propietario': 0.167,
#                                'quieran': 0.167,
#                                'ayudarás': 0.167,
#                                '?': 60.33,
#                                'inmortalidad': 0.167,
#                                '¿las': 0.167,
#                                'curiosidad': 0.501,
#                                '35': 0.167,
#                                '«hala': 0.167,
#                                'contentos': 0.167,
#                                'malos': 0.668,
#                                'presentarse': 0.334,
#                                'peseta': 0.167,
#                                'equivocado': 0.167,
#                                'separación': 0.167,
#                                'piscina': 1.838,
#                                'necesito': 0.334,
#                                'puñalada': 0.334,
#                                'íbamos': 0.334,
#                                'prisioneros': 1.003,
#                                'saludo': 0.167,
#                                'arrasoyarequin': 0.167,
#                                'molestado': 0.334,
#                                'niño': 0.501,
#                                'antro': 0.167,
#                                'patriota': 0.668,
#                                '¿lo': 0.167,
#                                'interesase': 0.167,
#                                'garita': 0.167,
#                                'convencimiento': 0.167,
#                                'podríamos': 0.167,
#                                'parpadeó': 0.167,
#                                'pasajeros': 0.167,
#                                'rocas': 0.167,
#                                'mendigos': 0.167,
#                                '¿la': 0.501,
#                                'morir': 0.334,
#                                'ocupan': 0.167,
#                                'engañarnos': 0.334,
#                                '¡canallas': 0.167,
#                                'ermita': 0.167,
#                                'favor': 1.17,
#                                'dió': 4.178,
#                                'entallada': 0.167,
#                                'aislado': 0.167,
#                                'verdad': 3.844,
#                                'enredos': 0.501,
#                                'realidad': 1.17,
#                                'seguramente': 0.334,
#                                'asistente': 0.334,
#                                'erguía': 0.167,
#                                'vagabundos': 0.334,
#                                'conminó': 0.167,
#                                'densa': 0.167,
#                                'llevaran': 0.167,
#                                'escoger': 0.167,
#                                'hacerse': 0.501,
#                                'anduvo': 0.167,
#                                'digno': 0.167,
#                                'telas': 0.167,
#                                'luxemburgo': 0.167,
#                                'vascongado': 0.668,
#                                'nuestra': 1.504,
#                                'zuaznavar': 1.003,
#                                'enredada': 0.167,
#                                'indagaciones': 0.334,
#                                'contestaron': 0.167,
#                                'revueltas': 0.167,
#                                'marcharme': 0.334,
#                                'aderezarla': 0.167,
#                                'hicieron': 2.173,
#                                'concluyó': 0.501,
#                                'violencia': 1.003,
#                                'movimientos': 0.167,
#                                'trabuco': 1.003,
#                                'señaló': 0.167,
#                                'agua': 1.17,
#                                'lodo': 0.167,
#                                'falsas': 0.668,
#                                'callejones': 0.167,
#                                'gaspar': 0.668,
#                                'pasaporte': 0.167,
#                                'meglio': 0.167,
#                                'leguías': 0.167,
#                                '¿tiene': 0.668,
#                                'inventaba': 0.167,
#                                'gustan': 0.167,
#                                'cuándo': 0.334,
#                                'enfermizo': 0.167,
#                                'violentos': 0.167,
#                                'comandante': 0.836,
#                                'madre': 3.175,
#                                'desorganizadores': 0.167,
#                                'llegar': 3.677,
#                                'gracias': 1.17,
#                                'estos': 6.016,
#                                'tocará': 0.167,
#                                'ausencia': 0.167,
#                                'mutismo': 0.167,
#                                '¿todo': 0.334,
#                                'empresas': 0.334,
#                                'repartían': 0.167,
#                                'ponemos': 0.167,
#                                'abandono': 0.167,
#                                'dictaminara': 0.167,
#                                'sienes': 0.167,
#                                'vió': 4.011,
#                                'vegetales': 0.167,
#                                'romántica': 0.167,
#                                'puesto': 1.003,
#                                'muy': 16.21,
#                                'alarmas': 0.167,
#                                'retreta': 0.167,
#                                'múzquiz': 0.167,
#                                'revolucionarios': 1.003,
#                                'tendrán': 0.501,
#                                'sujetaron': 0.501,
#                                '¿para': 1.17,
#                                'dicen': 0.501,
#                                'pánico': 0.167,
#                                'tiró': 0.836,
#                                'así': 5.515,
#                                'trascendentales': 0.167,
#                                'enigmático': 0.167,
#                                'sentí': 0.334,
#                                'efusión': 0.167,
#                                'asesino': 0.167,
#                                'publicaba': 0.167,
#                                'rojizos': 0.167,
#                                'prácticas': 0.167,
#                                'grito': 1.504,
#                                'bidian': 0.167,
#                                'treviño': 0.167,
#                                'realización': 0.334,
#                                'brutal': 0.167,
#                                'recuerdo': 1.838,
#                                'brotaban': 0.167,
#                                'pleno': 0.334,
#                                'importantes': 0.334,
#                                'capucha': 0.167,
#                                'discutía': 0.167,
#                                'inmediatamente': 1.838,
#                                'haciéndose': 0.167,
#                                'urrolara': 0.501,
#                                'desprecio': 0.334,
#                                '¿en': 0.334,
#                                'pareció': 1.337,
#                                'sacarle': 0.334,
#                                'autoridad': 0.501,
#                                'colina': 0.334,
#                                'natural': 2.34,
#                                'cochecito': 0.167,
#                                'majeza': 0.334,
#                                'toca': 0.334,
#                                'nombró': 0.167,
#                                'preparando': 0.167,
#                                'oficialito': 0.167,
#                                'cristo': 0.167,
#                                'nunca': 2.674,
#                                'echando': 0.334,
#                                'determinación': 0.334,
#                                'probabilidades': 0.167,
#                                'reconocen': 0.167,
#                                'intentó': 0.501,
#                                'guerras': 0.167,
#                                'disgustaría': 0.167,
#                                'curas': 0.668,
#                                'menor': 0.668,
#                                'monté': 0.167,
#                                'prohibido': 0.167,
#                                'símbolos': 0.167,
#                                'montaperras': 0.334,
#                                'carnaval': 0.167,
#                                'subvención': 0.167,
#                                'daban': 1.003,
#                                'solemnidad': 0.167,
#                                'tercería': 0.167,
#                                'espere': 0.167,
#                                'impresión': 1.003,
#                                'casa': 29.747,
#                                'períodos': 0.167,
#                                'fuga': 0.334,
#                                'tranquilo': 0.668,
#                                'escribió': 1.671,
#                                'desgraciados': 0.167,
#                                'publicarlo': 0.334,
#                                'acaso': 0.167,
#                                'aviene': 0.167,
#                                'pregunta': 0.334,
#                                'próximo': 1.003,
#                                'moscardoneo': 0.167,
#                                'dieran': 0.167,
#                                'colores': 0.167,
#                                'llevé': 0.501,
#                                'fabulosa': 0.167,
#                                'pacto': 0.167,
#                                'triunfo': 0.668,
#                                'insólito': 0.167,
#                                'infecto': 0.167,
#                                'verte': 0.334,
#                                'prosista': 0.334,
#                                'disparar': 0.167,
#                                'demagogia': 0.167,
#                                'acordó': 0.334,
#                                'quemaba': 0.167,
#                                'saltar': 0.334,
#                                'abundante': 0.167,
#                                'azcoitia': 1.17,
#                                'grado': 0.836,
#                                'buscan': 0.167,
#                                'esperaban': 0.167,
#                                'cuente': 0.334,
#                                'prendió': 0.167,
#                                'chocolate': 0.167,
#                                'recados': 0.334,
#                                'descifre': 0.167,
#                                'transversal': 0.167,
#                                'bolsillo': 1.003,
#                                'teresa': 0.167,
#                                'marqués': 0.501,
#                                'hoyos': 0.334,
#                                'viaje': 0.501,
#                                'bodegón': 0.167,
#                                'rebeldía': 0.167,
#                                'encerrara': 0.167,
#                                'nacimiento': 0.501,
#                                'impusieron': 0.167,
#                                'pegaban': 0.167,
#                                'jefes': 1.003,
#                                'chiquita': 0.167,
#                                'piedad': 0.167,
#                                'tonadilla': 0.167,
#                                'botines': 0.167,
#                                'mayor': 3.844,
#                                'aspiraba': 0.167,
#                                'manda': 0.167,
#                                'manuscrito': 0.167,
#                                'sabemos': 0.167,
#                                'fríamente': 0.167,
#                                'trazando': 0.167,
#                                'teja': 0.167,
#                                'charlatán': 0.167,
#                                'luego': 8.022,
#                                'separo': 0.167,
#                                'muchachos': 1.838,
#                                'luto': 0.668,
#                                'anacarsis': 0.501,
#                                'filadelfos': 1.003,
#                                'sangrientos': 0.167,
#                                'dormir': 1.003,
#                                'principio': 0.668,
#                                'atajo': 0.167,
#                                'reía': 0.334,
#                                'compungida': 0.167,
#                                'conservaba': 0.334,
#                                'templados': 0.167,
#                                'ejércitos': 0.167,
#                                'azufre': 0.167,
#                                'talud': 0.167,
#                                'paseando': 0.501,
#                                'exagero': 0.167,
#                                'país': 2.005,
#                                'diseminados': 0.167,
#                                'madrid': 4.178,
#                                'suficiencia': 0.167,
#                                'viniendo': 0.167,
#                                'giro': 0.334,
#                                'pencos': 0.167,
#                                'probable': 0.167,
#                                'gastó': 0.167,
#                                'intentarán': 0.167,
#                                'montón': 0.501,
#                                'espeluznante': 0.334,
#                                'abogando': 0.167,
#                                'disolvieron': 0.167,
#                                'trató': 0.501,
#                                'sordas': 0.334,
#                                'otana': 0.167,
#                                'entraba': 0.668,
#                                'respetabilidad': 0.167,
#                                'lleva': 0.501,
#                                'comía': 0.167,
#                                'tribu': 0.167,
#                                'interrumpir': 0.167,
#                                'preeminencia': 0.167,
#                                'primavera': 0.167,
#                                'quizá': 2.34,
#                                'querida': 0.334,
#                                'grave': 0.668,
#                                'brillantes': 0.334,
#                                '¡cuánto': 0.167,
#                                'archaya': 0.334,
#                                'cogiéndola': 0.167,
#                                'quemar': 0.334,
#                                'embestidas': 0.167,
#                                'rubio': 0.334,
#                                'herradura': 0.334,
#                                'donna.»': 0.167,
#                                'espantosas': 0.167,
#                                'dominaban': 0.167,
#                                'verse': 0.836,
#                                'observó': 0.167,
#                                'vela': 1.337,
#                                'truquenecoborda': 0.167,
#                                'causa': 2.005,
#                                'faroles': 0.167,
#                                'aventurero': 1.003,
#                                'intelectuales': 0.167,
#                                'pagado': 0.167,
#                                'resistencia': 0.167,
#                                'portillo': 0.334,
#                                'llamas': 0.501,
#                                'conspirador': 0.501,
#                                'iriberri': 0.334,
#                                'fracasó': 0.334,
#                                'pronto': 4.345,
#                                'miniatura': 0.334,
#                                'comprometerse': 0.167,
#                                'dolmán': 0.167,
#                                'abortado': 0.167,
#                                'encargos': 0.167,
#                                'obrar': 0.167,
#                                'almas': 0.167,
#                                'nací': 0.334,
#                                'bastante': 3.342,
#                                'guardar': 0.334,
#                                'datos': 0.334,
#                                'enemistades': 0.167,
#                                'molesta': 0.501,
#                                'blanquear': 0.167,
#                                'pedí': 0.334,
#                                'tallien': 0.334,
#                                'escalábamos': 0.167,
#                                'palo': 0.334,
#                                'generalizarse': 0.167,
#                                'corredor': 0.501,
#                                'burlones': 0.334,
#                                'chirriar': 0.167,
#                                'quedarnos': 0.501,
#                                'soltaron': 0.167,
#                                'pidiéndolos': 0.167,
#                                'pobremente': 0.334,
#                                'alrededores': 0.836,
#                                'lado': 4.178,
#                                'engaño': 0.167,
#                                'bebían': 0.167,
#                                'hacer': 10.696,
#                                'desnudarnos': 0.167,
#                                'véngate': 0.167,
#                                'venta': 1.003,
#                                'desdeñosos': 0.334,
#                                'insignificante': 0.167,
#                                'felipe': 0.334,
#                                'bromeando': 0.167,
#                                '¿verdad': 0.668,
#                                'saludado': 0.167,
#                                'fusilarle': 0.167,
#                                'calumnia': 0.167,
#                                'santander': 1.17,
#                                'apareciendo': 0.334,
#                                'húmedo': 0.167,
#                                '¿probablemente': 0.167,
#                                'servidumbre': 0.167,
#                                'gentes': 0.668,
#                                'flemático': 0.167,
#                                'caballería': 0.668,
#                                'caracol': 0.167,
#                                'ilusión': 0.334,
#                                'probablemente': 0.836,
#                                'quedaremos': 0.334,
#                                'presentarle': 0.167,
#                                'paso': 2.173,
#                                'hablaremos': 0.501,
#                                '¡si': 0.334,
#                                'varones': 0.668,
#                                'farol': 0.501,
#                                'enemistad': 0.167,
#                                'artesanos': 0.167,
#                                'preguntando': 0.167,
#                                'sacó': 2.674,
#                                'dejaban': 0.501,
#                                '20': 0.167,
#                                'prusiano': 0.167,
#                                'madres': 0.167,
#                                'maliciosa': 0.167,
#                                'derecho': 1.003,
#                                'restauración': 0.167,
#                                'flauta': 0.167,
#                                'materialismo': 0.167,
#                                'escondí': 0.167,
#                                'semia': 0.167,
#                                'corriendo': 0.334,
#                                'perros': 0.668,
#                                'unión': 0.334,
#                                'interiormente': 0.167,
#                                'míos': 0.501,
#                                'este': 15.709,
#                                'talento': 0.668,
#                                'otros': 6.35,
#                                'ocultar': 0.167,
#                                'luisa': 0.334,
#                                'amordazaron': 0.167,
#                                'llevaba': 3.342,
#                                'acentos': 0.167,
#                                'torres': 0.167,
#                                'ángel': 0.334,
#                                'quedamos': 0.668,
#                                'levanté': 0.167,
#                                'padre': 7.353,
#                                'defendido': 0.167,
#                                'reconocimiento': 0.167,
#                                'sucesos': 0.167,
#                                'vientre': 0.167,
#                                'acepté': 0.167,
#                                'defensores': 0.167,
#                                'confusión': 0.167,
#                                'zapatillas': 0.167,
#                                'abandonado': 0.167,
#                                'durar': 0.334,
#                                'fincas': 0.334,
#                                'construyendo': 0.167,
#                                'rechoncho': 0.167,
#                                'sociedades': 0.501,
#                                'gallinas': 0.167,
#                                'penetra': 0.167,
#                                'desesperado': 0.501,
#                                '33': 0.167,
#                                'ventas': 0.334,
#                                'subía': 0.668,
#                                '¿entonces': 0.167,
#                                'influir': 0.167,
#                                'serena': 0.334,
#                                'escopetas': 0.167,
#                                'vidrieras': 0.167,
#                                'gure': 0.167,
#                                'grotesco': 0.167,
#                                'influyó': 0.167,
#                                'borda': 0.167,
#                                '¿usted': 0.668,
#                                'robábamos': 0.167,
#                                'recorrió': 0.668,
#                                'eran': 7.687,
#                                'tradicionalismo': 0.334,
#                                'jansenista': 0.167,
#                                'sonrosadas': 0.167,
#                                'mota': 0.334,
#                                'índole': 0.167,
#                                'cogote': 0.167,
#                                'dantonianos': 0.167,
#                                'trompetas': 0.167,
#                                'frecuentaba': 0.334,
#                                'carácter': 1.337,
#                                'provocadores': 0.167,
#                                'bondad': 0.167,
#                                'algunos': 6.518,
#                                'campiña': 0.167,
#                                'char': 0.167,
#                                'rosellón': 0.167,
#                                'traían': 0.334,
#                                'escuac': 0.167,
#                                '(': 2.005,
#                                'incorporarlo': 0.167,
#                                'fuenlabrada': 0.167,
#                                'estremecerán': 0.167,
#                                'dices': 0.668,
#                                'tontería': 0.501,
#                                'volver': 1.671,
#                                'recobraron': 0.167,
#                                'aburres': 0.167,
#                                'agobiado': 0.167,
#                                'sorprender': 0.167,
#                                'risa': 0.334,
#                                'mayoría': 1.17,
#                                'salamanca': 0.334,
#                                'silencio': 1.17,
#                                'fuera': 5.849,
#                                'confidencias': 0.167,
#                                'servicial': 0.167,
#                                'dú': 0.167,
#                                'ramón': 0.334,
#                                'mostrara': 0.167,
#                                'quédate': 0.167,
#                                'desde': 11.364,
#                                'suponer': 0.501,
#                                'cebada': 0.167,
#                                'vacaciones': 0.167,
#                                'detalles': 0.668,
#                                'madrileñas': 0.167,
#                                'profusamente': 0.167,
#                                'salta': 0.167,
#                                'campañas': 0.167,
#                                'libremente': 0.167,
#                                'diabluras': 0.167,
#                                'exterior': 0.836,
#                                'blancas': 0.334,
#                                'recaían': 0.167,
#                                'abogado': 0.334,
#                                'alforja': 0.167,
#                                'jugarse': 0.167,
#                                'figurándome': 0.167,
#                                'pregúntale': 0.167,
#                                'mil': 0.334,
#                                'tramado': 0.167,
#                                'coman': 0.167,
#                                'dómine': 0.334,
#                                'estiércol': 0.334,
#                                'levita': 0.334,
#                                'málaga': 0.167,
#                                'duro': 0.334,
#                                'refugiamos': 0.167,
#                                'canciones': 0.836,
#                                'suizo': 0.167,
#                                'verlos': 0.167,
#                                'obscureciera': 0.167,
#                                'furiosa': 0.501,
#                                'comió': 0.334,
#                                'quedarte': 0.167,
#                                'atrevido': 0.668,
#                                'materialista': 0.167,
#                                'insultado': 0.334,
#                                'sagaz': 0.167,
#                                'compró': 0.167,
#                                'armados': 0.334,
#                                'almudena': 0.167,
#                                'alargó': 0.334,
#                                'ésta': 1.504,
#                                'balas': 0.501,
#                                'basados': 0.167,
#                                'repartía': 0.334,
#                                'pintada': 0.167,
#                                'repertorio': 0.167,
#                                'sopa': 0.501,
#                                'firmando': 0.167,
#                                'llamándole': 0.167,
#                                'realistas': 2.005,
#                                'estábamos': 0.836,
#                                'torero': 0.167,
#                                'careta': 0.167,
#                                'escu': 0.167,
#                                'nosotros': 2.507,
#                                '40': 0.167,
#                                'viveza': 0.501,
#                                'álamo': 0.167,
#                                'audaz': 0.836,
#                                'comerciantes': 0.167,
#                                'herejías': 0.167,
#                                'decíamos': 0.167,
#                                'contribuyendo': 0.167,
#                                'civil': 1.17,
#                                'rivalidades': 0.167,
#                                'estuviera': 0.836,
#                                'fuertemente': 0.334,
#                                'prosperará': 0.167,
#                                'acercó': 3.844,
#                                'tomarlos': 0.167,
#                                'granos': 0.334,
#                                'desligado': 0.167,
#                                'padece': 0.167,
#                                'maíces': 0.167,
#                                'une': 0.167,
#                                'viene': 1.003,
#                                '¿esto': 0.334,
#                                'urruña': 0.167,
#                                'sentimental': 0.167,
#                                'íntegros': 0.334,
#                                'folleto': 0.167,
#                                'dolores': 1.003,
#                                'agregó': 0.167,
#                                'insignificantes': 0.167,
#                                'implantar': 0.167,
#                                'simpática': 0.167,
#                                'alcobas': 0.334,
#                                'tranquila': 0.334,
#                                'danton': 1.337,
#                                'listo': 0.334,
#                                'neptuno': 0.167,
#                                'parecían': 0.668,
#                                '¡pse': 0.501,
#                                'guicciardini': 0.167,
#                                'monarquía': 0.501,
#                                'morar': 0.167,
#                                '¡hombre': 1.17,
#                                'brillaban': 0.167,
#                                'conocéis': 0.167,
#                                'maduras': 0.167,
#                                'transfigurado': 0.167,
#                                'moulins': 0.167,
#                                'palmadas': 0.334,
#                                'tanto': 2.34,
#                                'nacional': 0.668,
#                                'patrona': 0.334,
#                                '¿puedes': 0.167,
#                                'está': 7.019,
#                                'satírico': 0.167,
#                                'gime': 0.167,
#                                'daño': 0.334,
#                                'manifestaban': 0.167,
#                                'batalla': 0.334,
#                                'mendicidad': 0.167,
#                                'benedícite': 0.167,
#                                'berlina': 0.334,
#                                'arder': 0.167,
#                                'carlos': 1.003,
#                                'escuálido': 0.167,
#                                'estrasburgo': 0.167,
#                                'extranjeros': 0.167,
#                                'azulados': 0.167,
#                                'grandezas': 0.334,
#                                'creas': 0.167,
#                                'mínimo': 0.167,
#                                'dedicaron': 0.167,
#                                'perdió': 0.167,
#                                'vara': 0.167,
#                                'destaca': 0.167,
#                                'parisiense': 0.167,
#                                '¿están': 0.167,
#                                'esforzándose': 0.167,
#                                'pared': 1.671,
#                                'hagas': 0.167,
#                                'mantenía': 0.167,
#                                'impurezas': 0.167,
#                                'militares': 1.838,
#                                'cómicos': 0.167,
#                                'danzatu': 0.167,
#                                'triste': 0.668,
#                                'informes': 0.334,
#                                'plutón': 0.167,
#                                'indicarte': 0.167,
#                                'rubios': 0.167,
#                                'blasfemia': 0.334,
#                                'pasaban': 0.668,
#                                'repúblicas': 0.167,
#                                'madrileños': 0.167,
#                                'fracasado': 0.167,
#                                'lomas': 0.167,
#                                'respectivos': 0.167,
#                                'secretas': 0.167,
#                                'jacques': 0.334,
#                                'enviaría': 0.167,
#                                'abrieron': 0.334,
#                                'viña': 0.167,
#                                'servido': 0.334,
#                                'ataque': 0.501,
#                                'agradable': 0.334,
#                                'agentes': 0.334,
#                                'hevia': 0.501,
#                                'echaré': 0.167,
#                                '_lamías_': 0.334,
#                                'recién': 0.668,
#                                'diez': 1.504,
#                                'encarnada': 0.167,
#                                'costillas': 0.167,
#                                'partidaria': 0.167,
#                                'hacia': 5.348,
#                                'jugando': 0.167,
#                                'pegamos': 0.167,
#                                'lazo': 0.334,
#                                'meterse': 0.836,
#                                '¿cuándo': 0.167,
#                                'mí': 6.518,
#                                'seule': 0.167,
#                                'lectura': 0.334,
#                                'antonieta': 0.167,
#                                'erosi': 0.167,
#                                'bandada': 0.167,
#                                'sangre': 1.17,
#                                'pasamos': 0.334,
#                                'volubilidad': 0.167,
#                                'sectas': 0.167,
#                                'acababan': 0.668,
#                                'engaña': 0.501,
#                                'marchitas': 0.167,
#                                'gobernatzendu': 0.167,
#                                'galerías': 0.668,
#                                'ficción': 0.334,
#                                'enciclopedismo': 0.334,
#                                'positivistas': 0.167,
#                                'sobrina': 1.003,
#                                'jactaba': 0.167,
#                                'aguadores': 0.167,
#                                'eh': 0.501,
#                                'recordó': 0.167,
#                                'derrotas': 0.167,
#                                'definido': 0.167,
#                                'dirige': 0.668,
#                                'quiso': 1.003,
#                                'ditirambos': 0.167,
#                                'novelas': 0.167,
#                                'tienes': 1.504,
#                                'hospedado': 0.167,
#                                'dejaron': 0.501,
#                                'cinta': 0.167,
#                                'viajar': 0.167,
#                                'secretos': 0.167,
#                                'boína': 1.17,
#                                'indiferencia': 1.17,
#                                'nevadas': 0.167,
#                                'íntima': 0.334,
#                                'montados': 0.167,
#                                'mi': 27.909,
#                                'estamos': 1.17,
#                                'moler': 0.334,
#                                'pelos': 0.167,
#                                'campana': 0.334,
#                                'ribavellosa': 1.17,
#                                'villarrealco': 0.167,
#                                'siguiente': 2.34,
#                                'comparsa': 0.167,
#                                'dirigido': 0.668,
#                                'infantes': 0.167,
#                                'dije': 2.173,
#                                'llega': 0.334,
#                                'detuvieron': 0.167,
#                                '¿cierro': 0.167,
#                                'ancho': 0.334,
#                                'despidieron': 0.167,
#                                'influencia': 1.003,
#                                'disparates': 0.167,
#                                'tenidas': 0.167,
#                                'mis': 5.014,
#                                'consiguió': 0.501,
#                                'questo': 0.167,
#                                'sorprendió': 0.334,
#                                'adelante»': 0.167,
#                                'entendía': 0.167,
#                                'rodeado': 0.334,
#                                'iglesias': 1.003,
#                                'francos': 0.334,
#                                'pidiendo': 0.501,
#                                'bruscamente': 0.334,
#                                'hilarión': 0.167,
#                                'las': 74.702,
#                                'alborotó': 0.167,
#                                'cojan': 0.167,
#                                'barco': 1.17,
#                                'obscureciendo': 0.167,
#                                'sea': 1.337,
#                                'aldeas': 0.167,
#                                'mendigo': 0.334,
#                                'pálidos': 0.334,
#                                'enciende': 0.167,
#                                'teorías': 0.167,
#                                'carretera': 2.173,
#                                'agitan': 0.167,
#                                'posible': 1.838,
#                                'borrachos': 0.167,
#                                'clootz': 0.501,
#                                'vas': 0.836,
#                                'mental': 0.167,
#                                'parezcan': 0.167,
#                                'terrenos': 0.334,
#                                'aristocrático': 0.501,
#                                'obra': 0.501,
#                                'resultas': 0.167,
#                                'moderno': 0.167,
#                                'agresiva': 0.167,
#                                'furor': 0.167,
#                                'premio': 0.167,
#                                'suscripción': 0.167,
#                                '«ese': 0.167,
#                                'oyendo': 0.167,
#                                'debíamos': 0.334,
#                                'simpleza': 0.167,
#                                'infantería': 0.167,
#                                'cantados': 0.167,
#                                'caserío': 3.008,
#                                'maquinalmente': 0.167,
#                                '¡de': 0.167,
#                                'marca': 0.167,
#                                'legado': 0.167,
#                                'estrechos': 0.167,
#                                'vivir»': 0.167,
#                                'profundamente': 0.334,
#                                'parte': 5.014,
#                                'humo': 0.501,
#                                'mateo': 0.167,
#                                'sa': 0.167,
#                                'podían': 0.167,
#                                'agarró': 0.334,
#                                'ciertamente': 0.334,
#                                'especiales': 0.167,
#                                'estupefactos': 0.167,
#                                'creí': 0.167,
#                                'soltera': 0.334,
#                                'traído': 0.167,
#                                'silueta': 0.167,
#                                'palacio': 0.836,
#                                'historia': 2.34,
#                                'habilitada': 0.167,
#                                'llenos': 0.167,
#                                'eso': 7.186,
#                                'llamada': 0.501,
#                                'tonta': 0.167,
#                                'deshaciéndose': 0.167,
#                                'ligero': 0.167,
#                                'hablan': 0.334,
#                                'española': 0.501,
#                                'denominados': 0.167,
#                                'cubos': 0.334,
#                                'dueño': 0.668,
#                                'horriblemente': 0.167,
#                                'llamaban': 1.337,
#                                'credo': 0.334,
#                                'pensamos': 0.167,
#                                'patio': 1.17,
#                                'hablábamos': 0.334,
#                                'tuvierais': 0.167,
#                                'manubrio': 0.167,
#                                'reino': 0.334,
#                                'inteligencia': 0.668,
#                                'trigo': 0.167,
#                                'saliente': 0.167,
#                                'países': 0.167,
#                                'excéntrico': 0.167,
#                                'metió': 0.334,
#                                'benito': 0.334,
#                                'lavó': 0.167,
#                                'rodeados': 0.167,
#                                'consecuencias': 0.167,
#                                'puertecilla': 0.167,
#                                'quinqué': 0.334,
#                                'hundida': 0.167,
#                                'portu': 0.167,
#                                'pusiera': 0.167,
#                                'señoritas': 0.501,
#                                'majo': 0.167,
#                                'favorecer': 0.167,
#                                'abigarrado': 0.167,
#                                'escalando': 0.167,
#                                'discutían': 0.167,
#                                'gontrán': 0.167,
#                                'firma': 0.334,
#                                'oir': 1.504,
#                                'garitos': 0.167,
#                                'costó': 0.167,
#                                'gaztelumendi': 0.501,
#                                'hablaron': 0.668,
#                                'vieja': 7.186,
#                                'absoluta': 0.167,
#                                'infundirme': 0.167,
#                                'miserable': 0.167,
#                                'prado': 0.167,
#                                'salada': 0.167,
#                                'sufrido': 0.167,
#                                'dependiente': 0.167,
#                                'penalidades': 0.167,
#                                'crees': 0.334,
#                                'áspero': 0.167,
#                                'fosco': 0.167,
#                                'sol': 2.173,
#                                'democrático': 0.167,
#                                'babilonia': 0.167,
#                                'bárbara': 0.167,
#                                '¡estás': 0.167,
#                                'guardadores': 0.167,
#                                'visitar': 0.501,
#                                'blancura': 0.167,
#                                'siniestro': 0.334,
#                                'girondino': 0.334,
#                                'cizaña': 0.167,
#                                'orientarme': 0.167,
#                                'tacos': 0.167,
#                                'prudencia': 0.167,
#                                'pies': 0.836,
#                                'proyecto': 0.836,
#                                'parecerá': 0.167,
#                                'laster': 0.167,
#                                'tornaron': 0.167,
#                                'conocidos': 0.167,
#                                'carmín': 0.167,
#                                'pedazos': 0.836,
#                                'cerraban': 0.167,
#                                'mancha': 0.334,
#                                'religión': 0.836,
#                                'lord': 0.334,
#                                'solo': 1.838,
#                                'tomó': 1.337,
#                                'monstruos': 0.167,
#                                'sembrar': 0.167,
#                                'confidente': 0.167,
#                                'detuvo': 0.501,
#                                'varias': 4.846,
#                                '¿os': 0.167,
#                                'encabritado': 0.167,
#                                'patrocinaba': 0.167,
#                                'castaña': 0.167,
#                                'conspirar': 0.167,
#                                'ayudante': 0.167,
#                                'disfrazadas': 0.167,
#                                'jaungoicaren': 0.167,
#                                'primita': 0.167,
#                                'cieno': 0.167,
#                                'habrían': 0.167,
#                                'inutilidad': 0.334,
#                                'canalla': 1.003,
#                                'sabes': 1.504,
#                                'ilustración': 0.167,
#                                'entretenida': 0.167,
#                                'entraban': 1.003,
#                                'caballo': 3.844,
#                                'sabrás': 0.167,
#                                'costado': 0.167,
#                                'interiores': 0.167,
#                                'alegres': 0.167,
#                                'recomendada': 0.167,
#                                'verdadera': 0.836,
#                                'interesa': 0.167,
#                                'catarro': 0.167,
#                                'rondalla': 0.167,
#                                'debe': 1.003,
#                                'cuidaba': 0.167,
#                                'ventana': 4.178,
#                                'respecto': 0.167,
#                                'ducados': 0.167,
#                                'corneja': 0.167,
#                                'comprendí': 0.668,
#                                'mostraba': 0.668,
#                                'asientos': 0.167,
#                                'discípulo': 0.167,
# ...
#                                'errónea': 0.146,
#                                'sacas': 0.293,
#                                'oscuro': 0.732,
#                                'trabaje': 0.439,
#                                '—cállate': 0.439,
#                                'puntual': 0.146,
#                                'nacional': 0.293,
#                                'revestir': 0.146,
#                                'liturgia': 0.146,
#                                'patrona': 1.317,
#                                'está': 12.73,
#                                'tratar': 0.146,
#                                'diciéndote': 0.146,
#                                '—muy': 0.293,
#                                'apartándole': 0.146,
#                                'envejecen': 0.146,
#                                'resistirme': 0.146,
#                                'confundirá': 0.146,
#                                'retortero': 0.146,
#                                'incendio': 0.293,
#                                'hazlo': 0.146,
#                                'ponga': 0.878,
#                                'rita': 0.439,
#                                'mínimo': 0.293,
#                                'perdió': 0.293,
#                                'parisiense': 0.146,
#                                'desnudos': 0.146,
#                                'hagas': 0.585,
#                                'mantenía': 0.146,
#                                'absoluto': 0.293,
#                                'triste': 1.171,
#                                'informes': 0.146,
#                                'ansia': 0.439,
#                                'leche': 0.732,
#                                'sucumbimos': 0.146,
#                                'señorones': 0.146,
#                                'legítimo': 0.146,
#                                'tempestades': 0.146,
#                                'solar': 0.146,
#                                'demostrando': 0.146,
#                                'servido': 0.585,
#                                'ataque': 0.439,
#                                'agentes': 0.146,
#                                'visten': 0.146,
#                                'recién': 0.732,
#                                'diez': 0.585,
#                                'espléndido': 0.293,
#                                'mía—': 0.146,
#                                'líos': 0.293,
#                                'escritores': 0.439,
#                                'hacia': 1.024,
#                                'recelosidad': 0.146,
#                                'terremoto': 0.146,
#                                'despedirlo': 0.146,
#                                'transcurrido': 0.146,
#                                'lazo': 0.146,
#                                'meterse': 0.293,
#                                'mí': 15.949,
#                                'lectura': 0.439,
#                                'pretendiente': 0.439,
#                                'contagiarse': 0.146,
#                                'habérsete': 0.146,
#                                'traeré': 0.293,
#                                'entendimiento': 0.146,
#                                'cruzado': 0.146,
#                                'selló': 0.146,
#                                'alzó': 0.146,
#                                'engaña': 0.293,
#                                '—¿que': 0.293,
#                                '—¡víctima': 0.146,
#                                'dilataba': 0.146,
#                                'madera': 0.146,
#                                'sobrina': 1.756,
#                                'últimamente': 0.293,
#                                'eh': 0.439,
#                                'definido': 0.146,
#                                'cegado': 0.146,
#                                'piensen': 0.146,
#                                'dirige': 0.293,
#                                'pecuniaria': 0.293,
#                                'durmiendo—le': 0.146,
#                                'contestarla': 0.146,
#                                'quiso': 1.024,
#                                'molestias': 0.439,
#                                'solazarse': 0.146,
#                                'novelas': 0.878,
#                                'tienes': 3.073,
#                                'hábito': 0.146,
#                                'despierte': 0.293,
#                                'combativo': 0.146,
#                                'raya': 0.146,
#                                'pormenores': 0.146,
#                                '¡majestuosa': 0.146,
#                                'secretos': 0.585,
#                                'llevas': 0.439,
#                                'indiferencia': 0.146,
#                                'nevadas': 0.146,
#                                '¡hipocresía': 0.146,
#                                'estatuaria': 0.146,
#                                'papá': 0.146,
#                                'perladas': 0.146,
#                                'íntima': 1.024,
#                                'alumbrando': 0.146,
#                                'erudición': 0.146,
#                                'rodando': 0.146,
#                                '—¡mire': 0.146,
#                                'resolver': 0.146,
#                                'maliciosamente': 0.146,
#                                'acabé': 0.293,
#                                'adquiere': 0.146,
#                                'confundirse': 0.146,
#                                'tuvieras': 0.146,
#                                'mi': 43.165,
#                                'estamos': 0.878,
#                                'valerte': 0.146,
#                                'recrea': 0.146,
#                                '¡mujeres': 0.293,
#                                'siguiente': 0.732,
#                                'kultura': 0.146,
#                                '¿volverás': 0.146,
#                                'genérico': 0.293,
#                                '«¿y': 0.585,
#                                'dirigido': 0.439,
#                                'sucesión': 0.146,
#                                '—¿querrías': 0.146,
#                                'dije': 3.512,
#                                'llega': 0.878,
#                                'deploraba': 0.146,
#                                'despidieron': 0.146,
#                                'influencia': 0.146,
#                                'disparates': 0.439,
#                                'empezar': 0.732,
#                                'cerebros': 0.146,
#                                'poniéndose': 0.732,
#                                'cambiará': 0.146,
#                                'sorprendió': 0.146,
#                                'entendía': 0.439,
#                                'bruscamente': 0.439,
#                                'atravesó': 0.146,
#                                'las': 42.141,
#                                '_nivolesca_': 0.146,
#                                'mónadas': 0.146,
#                                'bóveda': 0.146,
#                                'sea': 8.048,
#                                'das': 0.293,
#                                'despidiéronse': 0.146,
#                                'mendigo': 0.293,
#                                'ángeles': 0.146,
#                                '—¿eh': 0.293,
#                                'preguntarme': 0.146,
#                                'embarazo': 0.293,
#                                'teorías': 0.146,
#                                'representa': 0.146,
#                                'oírme': 0.146,
#                                'recurrió': 0.146,
#                                'decirse': 0.585,
#                                'posible': 1.463,
#                                'tomen': 0.146,
#                                'vas': 1.317,
#                                'obra': 0.732,
#                                'llovía': 0.293,
#                                'encentaba': 0.146,
#                                'fábrica': 0.146,
#                                'melancólico': 0.585,
#                                'oyendo': 0.439,
#                                '—decía': 0.293,
#                                'huída': 0.146,
#                                'movemos': 0.146,
#                                'llegas': 0.146,
#                                'lanzadera': 0.146,
#                                'maquinalmente': 0.146,
#                                '¡de': 1.317,
#                                'todos': 7.755,
#                                'consolarme': 0.146,
#                                'palomina': 0.146,
#                                'legado': 0.293,
#                                'sueñan': 0.293,
#                                'profundamente': 0.585,
#                                'parte': 3.951,
#                                'humo': 0.146,
#                                'puede': 8.487,
#                                'grueso': 0.146,
#                                '_¡la': 0.146,
#                                'rompió': 0.585,
#                                'podían': 0.146,
#                                'ingenua': 0.439,
#                                '¿tiene': 0.439,
#                                'creencias': 0.146,
#                                'disponía': 0.146,
#                                'guapas': 0.146,
#                                'creí': 1.902,
#                                'aprendierais': 0.146,
#                                'soltera': 0.293,
#                                'ofensas': 0.146,
#                                '«aquí': 0.439,
#                                'traído': 0.439,
#                                'olimpo': 0.146,
#                                '—cásate': 0.293,
#                                'caminos': 0.585,
#                                'arrimadito': 0.146,
#                                'historia': 3.073,
#                                'llenos': 0.146,
#                                'quietecito': 0.293,
#                                'recordarme': 0.146,
#                                'eso': 27.216,
#                                'predicador': 0.146,
#                                'insinuado': 0.293,
#                                'hablan': 0.146,
#                                'arqueólogo': 0.293,
#                                'española': 0.146,
#                                'enamoraste': 0.146,
#                                'burlar': 0.293,
#                                'pintores': 0.146,
#                                'dueño': 0.146,
#                                'notar': 0.146,
#                                'horriblemente': 0.293,
#                                'mujer—interpeló': 0.146,
#                                'viste': 0.439,
#                                'perjudicando': 0.293,
#                                'molestaría': 0.146,
#                                'ladrarnos': 0.146,
#                                'acabada': 0.146,
#                                'manubrio': 0.293,
#                                'inteligencia': 0.439,
#                                'rosario.»': 0.146,
#                                'saliente': 0.146,
#                                'afrodisíacas': 0.146,
#                                'haberme': 0.878,
#                                'metió': 0.293,
#                                'prudencio': 0.146,
#                                'pingües': 0.146,
#                                '158': 0.146,
#                                'fortuita': 0.439,
#                                'paternal': 0.146,
#                                'lavó': 0.293,
#                                'ganarlas': 0.439,
#                                'consecuencias': 0.439,
#                                'desfiguramiento': 0.146,
#                                'recibirla': 0.146,
#                                'acata': 0.146,
#                                'acostumbrándonos': 0.146,
#                                'sonreía': 0.732,
#                                'desahogo': 0.585,
#                                'exactamente': 0.146,
#                                'echarse': 0.293,
#                                'candidato': 0.439,
#                                'oir': 1.756,
#                                'solicitante': 0.293,
#                                'lavóse': 0.146,
#                                'doy': 0.732,
#                                'fermín—': 0.732,
#                                'ceniza': 0.293,
#                                'vieja': 0.146,
#                                'luminosa': 0.439,
#                                'anunció': 0.146,
#                                'sostener': 0.293,
#                                'suplir': 0.146,
#                                'absoluta': 0.293,
#                                'estéril': 0.293,
#                                'revertió': 0.146,
#                                '—obedece': 0.146,
#                                'sufrido': 0.146,
#                                'antojo': 0.293,
#                                'despachaste': 0.146,
#                                'crees': 2.487,
#                                'áspero': 0.146,
#                                '¿domingo': 0.146,
#                                'sol': 1.463,
#                                'viviese': 0.293,
#                                'vuelvas': 0.146,
#                                'lengüeta': 0.146,
#                                'desmayar»': 0.146,
#                                'engañado': 1.463,
#                                'bárbara': 0.146,
#                                'comí': 0.146,
#                                'despachado': 0.293,
#                                'dudase': 0.293,
#                                'admirar': 0.146,
#                                'sacrificarme': 0.293,
#                                'pensarías': 0.146,
#                                'visitar': 0.146,
#                                '¿supongo': 0.146,
#                                'pesimista': 0.439,
#                                'devotos': 0.146,
#                                'sepamos': 0.293,
#                                'disparatado': 0.146,
#                                'perra': 0.585,
#                                'agridulce': 0.146,
#                                'pies': 1.317,
#                                'sazonado': 0.146,
#                                'yo—dijo': 0.146,
#                                'parecerá': 0.146,
#                                'conocidos': 0.146,
#                                '—mire': 0.585,
#                                'manía': 0.439,
#                                'desdichada': 0.146,
#                                'sentarla': 0.146,
#                                'empezarás': 0.146,
#                                'cerraban': 0.146,
#                                'escojer': 0.146,
#                                'religión': 1.463,
#                                'solo': 3.951,
#                                'tomó': 1.171,
#                                'lutos': 0.293,
#                                'exaltarme': 0.293,
#                                'existencia—la': 0.146,
#                                'teoría—añadió—': 0.146,
#                                'confidente': 0.439,
#                                'detuvo': 0.293,
#                                'excusas': 0.146,
#                                'varias': 0.439,
#                                '¿os': 0.293,
#                                'sigue': 0.732,
#                                'rechazase': 0.146,
#                                'directo': 0.146,
#                                'recorría': 0.146,
#                                'martirio': 0.146,
#                                'cánticos': 0.146,
#                                'combinatorio': 0.146,
#                                'bombas': 0.439,
#                                'nutrido': 0.146,
#                                'habrían': 0.146,
#                                ...})})

# %% [markdown]
# Finalmente visualizaremos de forma gráfica plot.
#
# Ya que solo nos interesan las frecuencias de las 6 palabras almacenadas en la lista 'words', lo especificaremos en el parametro 'samples'.

# %%
rel_cfdist.plot(samples=words, title="Frecuencias por 10000 palabras")
